# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('data-kmeans.csv')
data = dataset.values
# Out:
# [15 39]

# %%
n = data.shape[0]

x1 = data[:,0]
x2 = data[:,1]

plt.figure(1,figsize=(9,9))
plt.scatter(x1, x2, c='k', label='data')
plt.title('data point')
plt.legend()
plt.show()

# %%
k = 5 # number of cluster

labels = np.zeros(n) # initial cluster

for i in range(n):
    labels[i] = np.random.randint(k)
    
label_1 = (labels==0)
label_2 = (labels==1)
label_3 = (labels==2)
label_4 = (labels==3)
label_5 = (labels==4)

init_x1 = np.zeros(k)
init_x2 = np.zeros(k)

centroids = list(zip(init_x1, init_x2))

for i in range(k):
    points = [data[j] for j in range(n) if labels[j] == i]
    print(points)
    centroids[i] = compute_centroid(points)
    print(centroids[i])
    
plt.figure(2,figsize=(9,9))
plt.scatter(x1, x2, s=label_1*50, c='b', label='Cluster 1')
plt.scatter(x1, x2, s=label_2*50, c='c', label='Cluster 2')
plt.scatter(x1, x2, s=label_3*50, c='m', label='Cluster 3')
plt.scatter(x1, x2, s=label_4*50, c='y', label='Cluster 4')
plt.scatter(x1, x2, s=label_5*50, c='r', label='Cluster 5')
plt.title('Initial cluster')
plt.legend()
plt.show()
# Out:
# [array([15, 81], dtype=int64), array([20, 77], dtype=int64), array([21, 66], dtype=int64), array([24, 35], dtype=int64), array([34, 17], dtype=int64), array([38, 92], dtype=int64), array([40, 55], dtype=int64), array([40, 47], dtype=int64), array([40, 42], dtype=int64), array([43, 54], dtype=int64), array([44, 50], dtype=int64), array([44, 46], dtype=int64), array([46, 51], dtype=int64), array([49, 55], dtype=int64), array([49, 42], dtype=int64), array([50, 49], dtype=int64), array([54, 41], dtype=int64), array([54, 44], dtype=int64), array([58, 46], dtype=int64), array([61, 42], dtype=int64), array([61, 49], dtype=int64), array([62, 55], dtype=int64), array([63, 48], dtype=int64), array([65, 50], dtype=int64), array([65, 59], dtype=int64), array([69, 58], dtype=int64), array([71, 95], dtype=int64), array([71, 11], dtype=int64), array([71, 75], dtype=int64), array([72, 34], dtype=int64), array([74, 72], dtype=int64), array([77, 74], dtype=int64), array([78, 88], dtype=int64), array([78,  1], dtype=int64), array([87, 27], dtype=int64), array([87, 75], dtype=int64), array([93, 14], dtype=int64), array([97, 32], dtype=int64), array([97, 86], dtype=int64), array([99, 97], dtype=int64), array([103,  23], dtype=int64), array([126,  28], dtype=int64), array([137,  18], dtype=int64)]
# [63.41860465 51.18604651]
# [array([16,  6], dtype=int64), array([17, 76], dtype=int64), array([18,  6], dtype=int64), array([19, 72], dtype=int64), array([19, 14], dtype=int64), array([19, 99], dtype=int64), array([20, 15], dtype=int64), array([25,  5], dtype=int64), array([28, 61], dtype=int64), array([29, 87], dtype=int64), array([33,  4], dtype=int64), array([38, 35], dtype=int64), array([42, 60], dtype=int64), array([46, 55], dtype=int64), array([47, 59], dtype=int64), array([48, 59], dtype=int64), array([54, 53], dtype=int64), array([54, 55], dtype=int64), array([54, 46], dtype=int64), array([57, 55], dtype=int64), array([60, 42], dtype=int64), array([62, 41], dtype=int64), array([63, 52], dtype=int64), array([63, 54], dtype=int64), array([64, 42], dtype=int64), array([65, 43], dtype=int64), array([67, 43], dtype=int64), array([71, 35], dtype=int64), array([71,  9], dtype=int64), array([71, 75], dtype=int64), array([74, 10], dtype=int64), array([75,  5], dtype=int64), array([78, 16], dtype=int64), array([78,  1], dtype=int64), array([87, 63], dtype=int64), array([87, 13], dtype=int64), array([103,  69], dtype=int64), array([120,  79], dtype=int64)]
# [53.73684211 42.47368421]
# [array([15, 39], dtype=int64), array([16, 77], dtype=int64), array([17, 40], dtype=int64), array([19,  3], dtype=int64), array([20, 13], dtype=int64), array([21, 35], dtype=int64), array([23, 29], dtype=int64), array([23, 98], dtype=int64), array([24, 73], dtype=int64), array([28, 14], dtype=int64), array([28, 32], dtype=int64), array([29, 31], dtype=int64), array([33, 81], dtype=int64), array([39, 28], dtype=int64), array([47, 52], dtype=int64), array([48, 51], dtype=int64), array([60, 49], dtype=int64), array([60, 50], dtype=int64), array([63, 50], dtype=int64), array([70, 29], dtype=int64), array([73, 88], dtype=int64), array([77, 36], dtype=int64), array([78, 22], dtype=int64), array([78, 89], dtype=int64), array([78, 78], dtype=int64), array([79, 35], dtype=int64), array([85, 26], dtype=int64), array([87, 92], dtype=int64), array([88, 13], dtype=int64), array([88, 86], dtype=int64), array([103,  17], dtype=int64), array([120,  16], dtype=int64)]
# [53.65625 46.     ]
# [array([18, 94], dtype=int64), array([20, 79], dtype=int64), array([25, 73], dtype=int64), array([28, 82], dtype=int64), array([30,  4], dtype=int64), array([30, 73], dtype=int64), array([33, 92], dtype=int64), array([34, 73], dtype=int64), array([39, 36], dtype=int64), array([39, 65], dtype=int64), array([43, 60], dtype=int64), array([43, 41], dtype=int64), array([46, 46], dtype=int64), array([46, 56], dtype=int64), array([48, 50], dtype=int64), array([48, 59], dtype=int64), array([54, 54], dtype=int64), array([54, 52], dtype=int64), array([54, 42], dtype=int64), array([57, 58], dtype=int64), array([59, 55], dtype=int64), array([62, 48], dtype=int64), array([62, 59], dtype=int64), array([62, 56], dtype=int64), array([63, 43], dtype=int64), array([64, 46], dtype=int64), array([69, 91], dtype=int64), array([72, 71], dtype=int64), array([73, 73], dtype=int64), array([75, 93], dtype=int64), array([76, 40], dtype=int64), array([77, 12], dtype=int64), array([77, 97], dtype=int64), array([78, 90], dtype=int64), array([78, 20], dtype=int64), array([78, 73], dtype=int64), array([81, 93], dtype=int64), array([85, 75], dtype=int64), array([88, 15], dtype=int64), array([88, 69], dtype=int64), array([98, 15], dtype=int64), array([98, 88], dtype=int64), array([101,  24], dtype=int64), array([126,  74], dtype=int64)]
# [60.88636364 59.29545455]
# [array([33, 14], dtype=int64), array([37, 26], dtype=int64), array([37, 75], dtype=int64), array([39, 61], dtype=int64), array([40, 42], dtype=int64), array([42, 52], dtype=int64), array([43, 45], dtype=int64), array([48, 48], dtype=int64), array([48, 47], dtype=int64), array([50, 56], dtype=int64), array([54, 47], dtype=int64), array([54, 48], dtype=int64), array([54, 51], dtype=int64), array([54, 57], dtype=int64), array([58, 60], dtype=int64), array([59, 41], dtype=int64), array([60, 40], dtype=int64), array([60, 52], dtype=int64), array([60, 47], dtype=int64), array([62, 42], dtype=int64), array([63, 46], dtype=int64), array([65, 48], dtype=int64), array([67, 57], dtype=int64), array([67, 56], dtype=int64), array([67, 40], dtype=int64), array([70, 77], dtype=int64), array([73,  5], dtype=int64), array([73,  7], dtype=int64), array([76, 87], dtype=int64), array([78, 17], dtype=int64), array([78, 76], dtype=int64), array([79, 83], dtype=int64), array([81,  5], dtype=int64), array([86, 20], dtype=int64), array([86, 95], dtype=int64), array([87, 10], dtype=int64), array([93, 90], dtype=int64), array([99, 39], dtype=int64), array([101,  68], dtype=int64), array([103,  85], dtype=int64), array([113,   8], dtype=int64), array([113,  91], dtype=int64), array([137,  83], dtype=int64)]
# [68.53488372 49.86046512]

# %%
def compute_distance(a, b):

    dist = #distance between a and b#

    return dist

# %%
def compute_centroid(Z):

    center = np.mean(Z, axis=0)
    
    return center

# %%
def compute_label(z, M):

    label = #label of point z with a set of centroids M#
    
    return label

# %%
def compute_loss(C, M):

    loss = #compute loss#
    
    return loss

# %% [markdown]
# ## 1. Plot the data points [1pt]

# %%
plt.figure(1,figsize=(9,9))
plt.scatter(x1, x2, c='k', label='data')
plt.title('data point')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Visualise the initial condition of the point labels [1pt]

# %% [markdown]
# ## 3. Plot the loss curve [5pt]

# %% [markdown]
# ## 4. Plot the centroid of each clsuter [5pt]

# %% [markdown]
# ## 5. Plot the final clustering result [5pt]
